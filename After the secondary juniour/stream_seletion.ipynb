# %%
#data of the home page first part what is stream selection

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('stream_selection_data.csv')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Student_ID Major_Stream                 Minor_Specialization  \
# 0  ST_0000001      Science        PCM (Physics-Chemistry-Maths)
# 1  ST_0000002      Science      PCB (Physics-Chemistry-Biology)
# 2  ST_0000003      Science               PCMB (General Science)
# 3  ST_0000004         Arts         History-PolScience-Sociology
# 4  ST_0000005         Arts      Psychology-Economics-Literature
# 5  ST_0000006         Arts        Geography-History-PublicAdmin
# 6  ST_0000007     Commerce    Accountancy-BusinessStudies-Maths
# 7  ST_0000008     Commerce    Accountancy-Economics-Informatics
# 8  ST_0000009   Vocational  ITI Computer Operator & Programming
# 9  ST_0000010   Vocational    Diploma in Mechanical Engineering
#
#   Mid_Instruction   State_Region
# 0         English        Haryana
# 1         English      Telangana
# 2           Hindi  Uttar Pradesh
# 3           Hindi      Rajasthan
# 4         English          Delhi
# 5        Regional        Gujarat
# ...

# %%
df.head()
# Out:
#    Student_ID Major_Stream             Minor_Specialization Mid_Instruction  \
# 0  ST_0000001      Science    PCM (Physics-Chemistry-Maths)         English
# 1  ST_0000002      Science  PCB (Physics-Chemistry-Biology)         English
# 2  ST_0000003      Science           PCMB (General Science)           Hindi
# 3  ST_0000004         Arts     History-PolScience-Sociology           Hindi
# 4  ST_0000005         Arts  Psychology-Economics-Literature         English
#
#     State_Region
# 0        Haryana
# 1      Telangana
# 2  Uttar Pradesh
# 3      Rajasthan
# 4          Delhi

# %%
df.tail()
# Out:
#    Student_ID Major_Stream                 Minor_Specialization  \
# 5  ST_0000006         Arts        Geography-History-PublicAdmin
# 6  ST_0000007     Commerce    Accountancy-BusinessStudies-Maths
# 7  ST_0000008     Commerce    Accountancy-Economics-Informatics
# 8  ST_0000009   Vocational  ITI Computer Operator & Programming
# 9  ST_0000010   Vocational    Diploma in Mechanical Engineering
#
#   Mid_Instruction State_Region
# 5        Regional      Gujarat
# 6         English    Karnataka
# 7         English  Maharashtra
# 8         English   Tamil Nadu
# 9        Regional       Punjab

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            10 non-null     object
#  1   Major_Stream          10 non-null     object
#  2   Minor_Specialization  10 non-null     object
#  3   Mid_Instruction       10 non-null     object
#  4   State_Region          10 non-null     object
# dtypes: object(5)
# memory usage: 532.0+ bytes

# %%
df["Student_ID"]
# Out:
# 0    ST_0000001
# 1    ST_0000002
# 2    ST_0000003
# 3    ST_0000004
# 4    ST_0000005
# 5    ST_0000006
# 6    ST_0000007
# 7    ST_0000008
# 8    ST_0000009
# 9    ST_0000010
# Name: Student_ID, dtype: object
