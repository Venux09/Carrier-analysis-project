# %%
# bad decision data and their reasons in the form of the pie chart

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('bad_stream_selection_result.csv')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                  Stream / Education Choice Failure Risk (Unemployment Rate)  \
# 0         Generic Humanities / Arts Degree                    15.0% - 18.0%
# 1                 Generic Commerce / B.Com                    10.5% - 12.0%
# 2     Low-Tier Science / Engineering (PCM)     38.0% - 40.0% (Under Age 25)
# 3  Medical / PCMB (Without NEET Selection)   25.0% (NEET Dropout rate/idle)
# 4           Vocational / Technical Diploma                      3.1% - 4.2%
#
#   Regret Rate within 3 Years  \
# 0                      65.0%
# 1                      55.0%
# 2                        73%
# 3                        50%
# 4                      < 15%
#
#                        The Real-World Market Reality
# 0  High focus on rote memory; low market alignmen...
# 1  Oversaturated market; plain degrees fail witho...
# 2  Massive supply over-saturation; 5 million grad...
# 3  Students get trapped in multiple gap years wit...
# 4  Highest job-market absorption rate; severe sho...

# %%
df.head()
# Out:
#                  Stream / Education Choice Failure Risk (Unemployment Rate)  \
# 0         Generic Humanities / Arts Degree                    15.0% - 18.0%
# 1                 Generic Commerce / B.Com                    10.5% - 12.0%
# 2     Low-Tier Science / Engineering (PCM)     38.0% - 40.0% (Under Age 25)
# 3  Medical / PCMB (Without NEET Selection)   25.0% (NEET Dropout rate/idle)
# 4           Vocational / Technical Diploma                      3.1% - 4.2%
#
#   Regret Rate within 3 Years  \
# 0                      65.0%
# 1                      55.0%
# 2                        73%
# 3                        50%
# 4                      < 15%
#
#                        The Real-World Market Reality
# 0  High focus on rote memory; low market alignmen...
# 1  Oversaturated market; plain degrees fail witho...
# 2  Massive supply over-saturation; 5 million grad...
# 3  Students get trapped in multiple gap years wit...
# 4  Highest job-market absorption rate; severe sho...

# %%
df['Regret Rate within 3 Years'] = [65,55,73,50,15] #int(df['Regret Rate within 3 Years'])

# %%
df.isnull()
# Out:
#    Stream / Education Choice  Failure Risk (Unemployment Rate)  \
# 0                      False                             False
# 1                      False                             False
# 2                      False                             False
# 3                      False                             False
# 4                      False                             False
#
#    Regret Rate within 3 Years  The Real-World Market Reality
# 0                       False                          False
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False

# %%
df.dropna()
# Out:
#                  Stream / Education Choice  Failure Risk (Unemployment Rate)  \
# 0         Generic Humanities / Arts Degree                              16.5
# 1                 Generic Commerce / B.Com                              11.0
# 2     Low-Tier Science / Engineering (PCM)                              39.0
# 3  Medical / PCMB (Without NEET Selection)                              25.0
# 4           Vocational / Technical Diploma                               3.5
#
#    Regret Rate within 3 Years  \
# 0                          65
# 1                          55
# 2                          73
# 3                          50
# 4                          15
#
#                        The Real-World Market Reality
# 0  High focus on rote memory; low market alignmen...
# 1  Oversaturated market; plain degrees fail witho...
# 2  Massive supply over-saturation; 5 million grad...
# 3  Students get trapped in multiple gap years wit...
# ...

# %%
# df['Failure Risk (Unemployment Rate)'] = df['Failure Risk (Unemployment Rate)'].astype(int)

# %%
# df['Regret Rate within 3 Years'] = df['Regret Rate within 3 Years'].astype(int)

# %%
# df.dtypes

# %%
df['Failure Risk (Unemployment Rate)'] = [16.5,11,39,25,3.5]

# %%
# df[1:1] = [Stream / Education Choice,	Failure Risk (Unemployment Rate),	Regret Rate within 3 Years,	The Real-World Market Reality]

# %% [markdown]
# #####
