# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df = pd.read_csv('data1.csv')

# %%
df
# Out:
#              Education_System  Available_Science_Combinations  \
# 0                   India_PCM                               1
# 1                   India_PCB                               1
# 2                  India_PCMB                               1
# 3             USA_STEM_System                              15
# 4                 UK_A_Levels                              20
# 5   Canada_High_School_System                              18
# 6  Australia_Senior_Secondary                              16
# 7           Germany_Gymnasium                              12
# 8         Singapore_JC_System                              10
#
#    Flexibility_Score
# 0                  2
# 1                  2
# 2                  3
# 3                  9
# 4                 10
# 5                  9
# 6                  8
# 7                  7
# 8                  7

# %%
label = df['Education_System']
Score = df['Flexibility_Score']
plt.bar(label,Score,color = 'Black')
plt.xlabel("Educaton System",fontsize = 10)
plt.xticks(fontsize = 10,rotation = 45,ha = 'right')
plt.ylabel('Scores/10 [out of the 10 ]')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Monu Verma\AppData\Local\Temp\ipykernel_12680\3968959202.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
