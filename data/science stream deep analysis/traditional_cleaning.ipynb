# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df = pd.read_csv('data2.csv')

# %%
df
# Out:
#    Stream                         Career_Path  Historical_Avg_Salary_INR  \
# 0     PCB            General Physician (MBBS)                     360000
# 1     PCB           Specialist Doctor (MD/MS)                     600000
# 2     PCB                       Dentist (BDS)                     240000
# 3     PCB                Pharmacist (B.Pharm)                     180000
# 4     PCB             Registered Nurse (B.Sc)                     150000
# 5     PCB                 Veterinarian (BVSc)                     200000
# 6     PCB               Physiotherapist (BPT)                     180000
# 7     PCB            Medical Lab Technologist                     120000
# 8     PCB   Research Scientist (Microbiology)                     250000
# 9     PCB                     Biotechnologist                     220000
# 10    PCB             Ayurvedic Doctor (BAMS)                     180000
# 11    PCB           Homeopathic Doctor (BHMS)                     150000
# 12    PCM                 Mechanical Engineer                     280000
# 13    PCM                      Civil Engineer                     250000
# 14    PCM                 Electrical Engineer                     280000
# 15    PCM                   Chemical Engineer                     320000
# 16    PCM         Software Engineer (Core CS)                     360000
# 17    PCM                  Aerospace Engineer                     400000
# 18    PCM                  Architect (B.Arch)                     240000
# 19    PCM                    Commercial Pilot                     800000
# 20    PCM               Merchant Navy Officer                     450000
# 21    PCM              Actuary / Statistician                     350000
# 22    PCM    Production / Industrial Engineer                     240000
# 23    PCM         Geologist / Earth Scientist                     300000
# 24   PCMB                 Biomedical Engineer                     240000
# 25    PCM  Defense Services (Technical Entry)                     300000
# 26    PCM    Astrophysicist / Space Scientist                     350000
# 27    PCB            Nutritionist / Dietitian                     140000
# 28    PCM                 Automobile Engineer                     260000
# 29    PCB      Audiologist / Speech Therapist                     180000
#
#     Current_Avg_Salary_INR  Projected_Future_Salary_INR  \
# 0                   900000                      1500000
# 1                  1800000                      3000000
# 2                   450000                       700000
# 3                   350000                       550000
# 4                   320000                       500000
# 5                   550000                       850000
# 6                   400000                       650000
# 7                   280000                       420000
# 8                   600000                       950000
# 9                   500000                       800000
# 10                  420000                       680000
# 11                  380000                       550000
# 12                  550000                       800000
# 13                  500000                       750000
# 14                  580000                       850000
# 15                  650000                      1000000
# 16                  850000                      1400000
# 17                  800000                      1300000
# 18                  520000                       800000
# 19                 2400000                      3600000
# 20                 1200000                      1800000
# 21                  950000                      1600000
# 22                  480000                       700000
# 23                  700000                      1050000
# 24                  500000                       850000
# 25                  800000                      1200000
# 26                  750000                      1200000
# 27                  350000                       550000
# 28                  520000                       780000
# 29                  450000                       720000
#
#     Estimated_Annual_Aspirants  Estimated_Active_Professionals  \
# 0                      1200000                         1400000
# 1                       100000                          350000
# 2                       300000                          280000
# 3                       250000                          600000
# 4                       400000                         1800000
# 5                       500000                          750000
# 6                       800000                          120000
# 7                       150000                          500000
# 8                        90000                          110000
# 9                       120000                          150000
# 10                      150000                          400000
# 11                      100000                          300000
# 12                      350000                         1200000
# 13                      400000                         1500000
# 14                      300000                         1000000
# 15                       80000                          250000
# 16                      800000                         4500000
# 17                       40000                           60000
# 18                      100000                          250000
# 19                       15000                           25000
# 20                       40000                           80000
# 21                       20000                           50000
# 22                       80000                          350000
# 23                       15000                           45000
# 24                       50000                           90000
# 25                      500000                           60000
# 26                       25000                           15000
# 27                       70000                          110000
# 28                      120000                          400000
# 29                       15000                           35000
#
#                Market_Saturation_Status
# 0         Under-saturated / High Demand
# 1                Highly Under-saturated
# 2                      Highly Saturated
# 3                             Saturated
# 4                       Balanced Demand
# 5                       Under-saturated
# 6                       Balanced Demand
# 7                             Saturated
# 8                       Balanced Demand
# 9       Saturated / Low Local Core Jobs
# 10            Balanced / Growing Demand
# 11                            Saturated
# 12                     Highly Saturated
# 13                     Highly Saturated
# 14                            Saturated
# 15                      Balanced Demand
# 16      Highly Saturated at Entry Level
# 17              Under-saturated / Niche
# 18                            Saturated
# 19  Under-saturated / High Cost Barrier
# 20                      Balanced Demand
# 21                      Under-saturated
# 22                            Saturated
# 23                      Balanced Demand
# 24                      Balanced Demand
# 25   Highly Competitive / Under-staffed
# 26                 Niche / Low Openings
# 27                      Balanced Demand
# 28                            Saturated
# 29                      Under-saturated

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Stream                          30 non-null     object
#  1   Career_Path                     30 non-null     object
#  2   Historical_Avg_Salary_INR       30 non-null     int64
#  3   Current_Avg_Salary_INR          30 non-null     int64
#  4   Projected_Future_Salary_INR     30 non-null     int64
#  5   Estimated_Annual_Aspirants      30 non-null     int64
#  6   Estimated_Active_Professionals  30 non-null     int64
#  7   Market_Saturation_Status        30 non-null     object
# dtypes: int64(5), object(3)
# memory usage: 2.0+ KB

# %%
np.max(df['Historical_Avg_Salary_INR'])
# Out:
# 800000

# %%
np.max(df['Projected_Future_Salary_INR']/100000)
# Out:
# 36.0

# %%
df_pcb = df.loc[0:11].copy()#creating different dataframes for both pcm and pcB
df_pcm  = df.loc[12:29].copy()

# %%
df_pcb
# Out:
#    Stream                        Career_Path  Historical_Avg_Salary_INR  \
# 0     PCB           General Physician (MBBS)                     360000
# 1     PCB          Specialist Doctor (MD/MS)                     600000
# 2     PCB                      Dentist (BDS)                     240000
# 3     PCB               Pharmacist (B.Pharm)                     180000
# 4     PCB            Registered Nurse (B.Sc)                     150000
# 5     PCB                Veterinarian (BVSc)                     200000
# 6     PCB              Physiotherapist (BPT)                     180000
# 7     PCB           Medical Lab Technologist                     120000
# 8     PCB  Research Scientist (Microbiology)                     250000
# 9     PCB                    Biotechnologist                     220000
# 10    PCB            Ayurvedic Doctor (BAMS)                     180000
# 11    PCB          Homeopathic Doctor (BHMS)                     150000
#
#     Current_Avg_Salary_INR  Projected_Future_Salary_INR  \
# 0                   900000                      1500000
# 1                  1800000                      3000000
# 2                   450000                       700000
# 3                   350000                       550000
# 4                   320000                       500000
# 5                   550000                       850000
# 6                   400000                       650000
# 7                   280000                       420000
# 8                   600000                       950000
# 9                   500000                       800000
# 10                  420000                       680000
# 11                  380000                       550000
#
#     Estimated_Annual_Aspirants  Estimated_Active_Professionals  \
# 0                      1200000                         1400000
# 1                       100000                          350000
# 2                       300000                          280000
# 3                       250000                          600000
# 4                       400000                         1800000
# 5                       500000                          750000
# 6                       800000                          120000
# 7                       150000                          500000
# 8                        90000                          110000
# 9                       120000                          150000
# 10                      150000                          400000
# 11                      100000                          300000
#
#            Market_Saturation_Status
# 0     Under-saturated / High Demand
# 1            Highly Under-saturated
# 2                  Highly Saturated
# 3                         Saturated
# 4                   Balanced Demand
# 5                   Under-saturated
# 6                   Balanced Demand
# 7                         Saturated
# 8                   Balanced Demand
# 9   Saturated / Low Local Core Jobs
# 10        Balanced / Growing Demand
# 11                        Saturated

# %%
df_pcb.groupby('Stream')['Current_Avg_Salary_INR'].agg(['mean','min','max'])
# Out:
#                  mean     min      max
# Stream
# PCB     579166.666667  280000  1800000

# %%
df.groupby('Stream')['Current_Avg_Salary_INR'].agg(['mean','min','max'])
# Out:
#                  mean     min      max
# Stream
# PCB     553571.428571  280000  1800000
# PCM     816666.666667  480000  2400000
# PCMB    500000.000000  500000   500000

# %%
df_pcb
# Out:
#    Stream                        Career_Path  Historical_Avg_Salary_INR  \
# 0     PCB           General Physician (MBBS)                     360000
# 1     PCB          Specialist Doctor (MD/MS)                     600000
# 2     PCB                      Dentist (BDS)                     240000
# 3     PCB               Pharmacist (B.Pharm)                     180000
# 4     PCB            Registered Nurse (B.Sc)                     150000
# 5     PCB                Veterinarian (BVSc)                     200000
# 6     PCB              Physiotherapist (BPT)                     180000
# 7     PCB           Medical Lab Technologist                     120000
# 8     PCB  Research Scientist (Microbiology)                     250000
# 9     PCB                    Biotechnologist                     220000
# 10    PCB            Ayurvedic Doctor (BAMS)                     180000
# 11    PCB          Homeopathic Doctor (BHMS)                     150000
#
#     Current_Avg_Salary_INR  Projected_Future_Salary_INR  \
# 0                   900000                      1500000
# 1                  1800000                      3000000
# 2                   450000                       700000
# 3                   350000                       550000
# 4                   320000                       500000
# 5                   550000                       850000
# 6                   400000                       650000
# 7                   280000                       420000
# 8                   600000                       950000
# 9                   500000                       800000
# 10                  420000                       680000
# 11                  380000                       550000
#
#     Estimated_Annual_Aspirants  Estimated_Active_Professionals  \
# 0                      1200000                         1400000
# 1                       100000                          350000
# 2                       300000                          280000
# 3                       250000                          600000
# 4                       400000                         1800000
# 5                       500000                          750000
# 6                       800000                          120000
# 7                       150000                          500000
# 8                        90000                          110000
# 9                       120000                          150000
# 10                      150000                          400000
# 11                      100000                          300000
#
#            Market_Saturation_Status
# 0     Under-saturated / High Demand
# 1            Highly Under-saturated
# 2                  Highly Saturated
# 3                         Saturated
# 4                   Balanced Demand
# 5                   Under-saturated
# 6                   Balanced Demand
# 7                         Saturated
# 8                   Balanced Demand
# 9   Saturated / Low Local Core Jobs
# 10        Balanced / Growing Demand
# 11                        Saturated

# %%
#bar graph for the the salary comparison

# %%
carrier = df_pcb['Career_Path']
current_salaries = df_pcb['Current_Avg_Salary_INR']

# %%
#Plotting the bar 
carrier = df_pcb['Career_Path']
current_salaries = df_pcb['Current_Avg_Salary_INR']
plt.bar(carrier,current_salaries/100000,color= 'blue')
plt.xlabel('Carrier names')
plt.ylabel('Salaries[LPA]')
plt.title('The salaries of the job of the pcb with Career names')
plt.xticks(rotation = 45,fontsize = 7)
plt.legend()
plt.tight_layout()
plt.style.use('dark_background')
# Out:
# C:\Users\Monu Verma\AppData\Local\Temp\ipykernel_4532\3843542707.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Plotting the bar 
carrier = df_pcm['Career_Path']
current_salaries = df_pcm['Current_Avg_Salary_INR']
plt.bar(carrier,current_salaries/100000,color= 'blue')
plt.xlabel('Carrier names')
plt.ylabel('Salaries[LPA]')
plt.title('The salaries of the job of the pcm with Career names')
plt.xticks(rotation = 45,fontsize = 6.5)
plt.legend()
plt.tight_layout()
plt.style.use('dark_background')
# Out:
# C:\Users\Monu Verma\AppData\Local\Temp\ipykernel_4532\124986950.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
