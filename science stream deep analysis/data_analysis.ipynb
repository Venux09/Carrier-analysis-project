# %% [raw]
# This dataset represents a sample of 5,000 senior secondary schools surveyed across different regions (Urban/Rural) and management types (Government/Private)

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('schools_science_combination_data.csv')

# %%
df
# Out:
#   School_Category Location_Type Management_Type  Total_Schools  \
# 0      Category A         Urban         Private           1500
# 1      Category B         Urban      Government           1000
# 2      Category C         Rural         Private           1200
# 3      Category D         Rural      Government           1300
# 4           Total           NaN           Total           5000
#
#    Restricted_Streams_No_Guidance  Comprehensive_Streams_With_Guidance
# 0                             350                                 1150
# 1                             650                                  350
# 2                             720                                  480
# 3                            1050                                  250
# 4                            2770                                 2230

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   School_Category                      5 non-null      object
#  1   Location_Type                        4 non-null      object
#  2   Management_Type                      5 non-null      object
#  3   Total_Schools                        5 non-null      int64
#  4   Restricted_Streams_No_Guidance       5 non-null      int64
#  5   Comprehensive_Streams_With_Guidance  5 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 372.0+ bytes

# %%
df.isnull()
# Out:
#    School_Category  Location_Type  Management_Type  Total_Schools  \
# 0            False          False            False          False
# 1            False          False            False          False
# 2            False          False            False          False
# 3            False          False            False          False
# 4            False           True            False          False
#
#    Restricted_Streams_No_Guidance  Comprehensive_Streams_With_Guidance
# 0                           False                                False
# 1                           False                                False
# 2                           False                                False
# 3                           False                                False
# 4                           False                                False

# %%
df.fillna('4',inplace=True)

# %%
df
# Out:
#   School_Category Location_Type Management_Type  Total_Schools  \
# 0      Category A         Urban         Private           1500
# 1      Category B         Urban      Government           1000
# 2      Category C         Rural         Private           1200
# 3      Category D         Rural      Government           1300
# 4           Total             -           Total           5000
#
#    Restricted_Streams_No_Guidance  Comprehensive_Streams_With_Guidance
# 0                             350                                 1150
# 1                             650                                  350
# 2                             720                                  480
# 3                            1050                                  250
# 4                            2770                                 2230
